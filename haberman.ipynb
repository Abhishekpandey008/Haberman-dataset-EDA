# %% [markdown]
# # Data Set Information:
#
# The dataset contains cases from a study that was conducted between 1958 and 1970 at the University of Chicago's
# Billings Hospital on the survival of patients who had undergone surgery for breast cancer.

# %% [markdown]
# # Attribute Information:
#
# 1. Age of patient at time of operation (numerical)
# 2. Patient's year of operation (year - 1900, numerical)
# 3. Number of positive axillary nodes detected (numerical)
# 4. Survival status (class attribute)
# -- 1 = the patient survived 5 years or longer
# -- 2 = the patient died within 5 year

# %%
# Importing neccesary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#importing dataset
haberman =pd.read_csv("haberman.csv")

# %%
#Printing data points and feature
print(haberman.shape)
# Out:
# (305, 4)

# %%
#Printing all the columns
print(haberman.columns)
# Out:
# Index(['30', '64', '1', '1.1'], dtype='object')

# %%
#Renaming column names for better understanding
haberman = haberman.rename(columns = {"30" : "age", "64" : "operation_year", "1" : "axillary_lymph_node", "1.1" : "survival_status"})

# %%
#printing renamed columns
print(haberman.columns)
# Out:
# Index(['age', 'operation_year', 'axillary_lymph_node', 'survival_status'], dtype='object')

# %%
#Printing first 5 rows
haberman.head()
# Out:
#    age  operation_year  axillary_lymph_node  survival_status
# 0   30              62                    3                1
# 1   30              65                    0                1
# 2   31              59                    2                1
# 3   31              65                    4                1
# 4   33              58                   10                1

# %%
#printing last 5 rows
haberman.tail()
# Out:
#      age  operation_year  axillary_lymph_node  survival_status
# 300   75              62                    1                1
# 301   76              67                    0                1
# 302   77              65                    3                1
# 303   78              65                    1                2
# 304   83              58                    2                2

# %%
#Printing statistical measure for each column
haberman.describe()
# Out:
#               age  operation_year  axillary_lymph_node  survival_status
# count  305.000000      305.000000           305.000000       305.000000
# mean    52.531148       62.849180             4.036066         1.265574
# std     10.744024        3.254078             7.199370         0.442364
# min     30.000000       58.000000             0.000000         1.000000
# 25%     44.000000       60.000000             0.000000         1.000000
# 50%     52.000000       63.000000             1.000000         1.000000
# 75%     61.000000       66.000000             4.000000         2.000000
# max     83.000000       69.000000            52.000000         2.000000

# %%
#To differentiate between class
haberman["survival_status"].value_counts()
#Survival status 1 = the patient survived 5 years or longer 2 = the patient died within 5 year
# Out:
# 1    224
# 2     81
# Name: survival_status, dtype: int64

# %% [markdown]
# # Objective:-
# To classify or predict patient survival who had undergone surgery for breast cancer

# %% [markdown]
# # Univariate analysis:
#
#
#    # Histrogram

# %%
sns.FacetGrid(haberman, hue="survival_status", height=5) \
   .map(sns.histplot, "age") \
   .add_legend();
plt.title("Histrogram of age")
plt.show();

# %%
sns.FacetGrid(haberman, hue="survival_status", height=5) \
   .map(sns.histplot, 'operation_year') \
   .add_legend();
plt.title("Histrogram of operation year ")
plt.show();

# %%
sns.FacetGrid(haberman, hue="survival_status", height=5) \
   .map(sns.histplot, "axillary_lymph_node") \
   .add_legend();
plt.title("Histrogram of axillary lymph node")
plt.show();

# %% [raw]
# observation:
# >patients aged between 40-60 tends to live more than five year ,also die more frequently within 5 year after surgery
# >More than 110 people live with 0-5 axillary lymph node ,40+ died as well.

# %% [markdown]
# # PDF and CDF

# %%
#Dividing survival dataset into two parts
survival1=haberman.loc[haberman["survival_status"]==1]
survival2=haberman.loc[haberman["survival_status"]==2]

# %%
#PDF
counts,bin_edges=np.histogram(survival1["age"],bins=10,density=True)
pdf=counts/sum(counts)
#CDF
cdf=np.cumsum(pdf)
plt.title("Pdf and cdf of age")
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:], cdf)
#PDF
counts,bin_edges=np.histogram(survival2["age"],bins=10,density=True)
pdf=counts/sum(counts)
#CDF
cdf=np.cumsum(pdf)
plt.title("Pdf and cdf of age")
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:], cdf)
plt.xlabel("age")
# Out:
# Text(0.5, 0, 'age')

# %%
#PDF
counts,bin_edges=np.histogram(survival1["axillary_lymph_node"],bins=10,density=True)
pdf=counts/sum(counts)

#CDF
cdf=np.cumsum(pdf)
plt.title("Pdf and cdf of age")
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:], cdf)

#PDF
counts,bin_edges=np.histogram(survival2["axillary_lymph_node"],bins=10,density=True)
pdf=counts/sum(counts)

#CDF
cdf=np.cumsum(pdf)
plt.title("Pdf and cdf of axillary lymph node")
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:], cdf)
plt.xlabel("axillary lymph node")
plt.show()

# %%
#PDF
counts,bin_edges=np.histogram(survival1["operation_year"],bins=10,density=True)
pdf=counts/sum(counts)

#CDF
cdf=np.cumsum(pdf)
plt.title("Pdf and cdf of age")
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:], cdf)

#PDF
counts,bin_edges=np.histogram(survival2["operation_year"],bins=10,density=True)
pdf=counts/sum(counts)

#CDF
cdf=np.cumsum(pdf)
plt.title("Pdf and cdf of operation year")
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:], cdf)
plt.xlabel("operation year")
plt.show()

# %% [raw]
# observation:
# >More than  80% people survived with positive axillary lymph node <10
# > About 40% died between age 50-65

# %% [markdown]
# # Box Plot

# %%
#Box plot
sns.boxplot(x="survival_status",y="age",data=haberman)
plt.title("Box plot of age")
plt.show()

# %%
#Box plot
sns.boxplot(x="survival_status",y="axillary_lymph_node",data=haberman)
plt.title("Box plot of axillary lymph node")
plt.show()

# %%
#Box plot
sns.boxplot(x="survival_status",y="operation_year",data=haberman)
plt.title("Box plot of operation year")
plt.show()

# %% [markdown]
# # Violin Plot

# %%
#violin plot
sns.violinplot(x="survival_status",y="operation_year",data=haberman,size=8)
plt.title("violin plot of operation year")
plt.show()

# %%
#violin plot
sns.violinplot(x="survival_status",y="age",data=haberman,size=8)
plt.title("violin plot of age")
plt.show()

# %%
#violin plot
sns.violinplot(x="survival_status",y="axillary_lymph_node",data=haberman,size=8)
plt.title("violin plot of axillary lymph node")
plt.show()

# %% [markdown]
# # Bivariate Analysis
#
# # Scatter Plot

# %%
#scatter plot
sns.set_style("whitegrid");
sns.FacetGrid(haberman, hue="survival_status", height=4) \
   .map(plt.scatter, "age", "operation_year") \
   .add_legend();
plt.title("Scatter plot of age and operation year")
plt.show();

# %%
#scatter plot
sns.set_style("whitegrid");
sns.FacetGrid(haberman, hue="survival_status", height=4) \
   .map(plt.scatter, "age", "axillary_lymph_node") \
   .add_legend();
plt.title("Scatter plot of age and axillary lymph node")
plt.show();

# %% [markdown]
# # Pair Plot

# %%
#Pair Plot
plt.close()
sns.set_style("whitegrid")
sns.pairplot(haberman,hue="survival_status",height=3)
plt.title("Pair plot")
plt.show()

# %% [raw]
# observation:
# >Both the scatter plot and pair plot is very fudgy and overlapping hence it is diffcult to conclude anything.

# %% [markdown]
# # Conclusion:

# %% [raw]
# >Data set is imbalanced ,it does not contain equal no. of dataset.
# >Most of the data is linearly inseparable form each class. There are overlapping and fudginess.
# >But somehow axillary_lymph_node and age is giving some intution in the dataset.
# >we can not build a model simply using  if else condition we need to have some more complex technique to handle this dataset.
